# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set()

# %% [markdown]
# # Bar Chart

# %%
df_used_cars= pd.read_csv("bar_chart_data.csv")

# %%
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize=(9,6))
plt.bar(x= df_used_cars["Brand"], height= df_used_cars["Cars Listings"], color= "midnightblue")
plt.xticks(rotation=45, fontsize=13)
plt.yticks(fontsize= 13)
plt.title("Cars listings by Brand", fontsize= 13, fontweight= 'bold')
plt.ylabel("Cars Listibg", fontsize= 13)
plt.savefig("Used Cars Bar.png")
plt.show()

# %%
df_icecream= pd.read_csv("E:\\365\\Data Visualization\\3. Bar Chart\\Howework\\bar_chart_ice_cream.csv")
df_icecream
# Out:
#           Cities  Frequency
# 0       New York      12327
# 1             LA      17129
# 2  San Francisco      19923

# %%
plt.figure(figsize=(9,6))
plt.bar(x= df_icecream["Cities"],height= df_icecream["Frequency"], color= "midnightblue")
plt.ylabel("Frequencies")
plt.xticks(fontsize= 13)
plt.yticks(fontsize=13)
plt.title("Ice Cream Shop Sale", fontsize=14, fontweight= 'bold')
plt.savefig("Icecream-1")
plt.show()

# %%
plt.barh(y= df_icecream["Cities"],width= df_icecream["Frequency"], color= "midnightblue")
plt.xlabel("Frequencies")
plt.xticks(fontsize= 13)
plt.yticks(fontsize=13)
plt.title("Ice Cream Shor Sale", fontsize=14, fontweight= 'bold')
plt.savefig("Icecream-2")
plt.show()

# %% [markdown]
# # Histogram

# %%
df_customer_survey = pd.read_csv("histogram_survey_data.csv")
df_customer_survey
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0
#
# [2000 rows x 8 columns]

# %%
sns.set_style("white")
plt.figure(figsize = (8, 6))
plt.hist(df_customer_survey["Age"],
         bins = 12, 
         color = "darkseagreen")
plt.xticks(np.arange(min(df_customer_survey["Age"]), max(df_customer_survey["Age"]),5.0))
plt.xlabel("Age")
plt.ylabel("Number of Participants")
sns.despine()
plt.show()

# %% [markdown]
# # Line Chart

# %%
df_spx_ftse_10_20 = pd.read_csv("returns1020.csv")
df_spx_ftse_10_20
# Out:
#            Date   GSPCRet   FTSERet
# 0      1/1/2010  0.000000  0.000000
# 1      1/4/2010 -0.008912  0.000000
# 2      1/5/2010  0.014419  0.016147
# 3      1/6/2010  0.002693  0.004036
# 4      1/7/2010  0.000493  0.001358
# ...         ...       ...       ...
# 2626  1/27/2020 -0.025784  0.010429
# 2627  1/28/2020  0.002522 -0.022924
# 2628  1/29/2020  0.010478  0.009255
# 2629  1/30/2020 -0.010035  0.000388
# 2630  1/31/2020  0.007947 -0.013576
#
# [2631 rows x 3 columns]

# %%
df_spx_ftse_10_20["new_date"] = pd.to_datetime(df_spx_ftse_10_20["Date"])
df_spx_ftse_10_20["new_date"]
# Out:
# 0      2010-01-01
# 1      2010-01-04
# 2      2010-01-05
# 3      2010-01-06
# 4      2010-01-07
#           ...
# 2626   2020-01-27
# 2627   2020-01-28
# 2628   2020-01-29
# 2629   2020-01-30
# 2630   2020-01-31
# Name: new_date, Length: 2631, dtype: datetime64[ns]

# %%
labels = ["S&P 500", "FTSE 100"]
plt.figure(figsize = (20, 8))
plt.plot(df_spx_ftse_10_20["new_date"], df_spx_ftse_10_20["GSPCRet"])
plt.plot(df_spx_ftse_10_20["new_date"], df_spx_ftse_10_20["FTSERet"])
plt.title("S&P vs FTSE Returns (2010 - 2020)", fontsize = 14, fontweight = "bold")
plt.ylabel("Returns")
plt.xlabel("Date")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %%
# The data for second half of 2015 is required:
df_spx_ftse_H2_15 = df_spx_ftse_10_20[(df_spx_ftse_10_20.new_date >= '2015-07-01') &
                                      (df_spx_ftse_10_20.new_date <= '2015-12-31')]

df_spx_ftse_H2_15
# Out:
#             Date   GSPCRet   FTSERet   new_date
# 1433    7/1/2015  0.002819 -0.015029 2015-07-01
# 1434    7/2/2015  0.005336  0.013434 2015-07-02
# 1435    7/3/2015  0.000000  0.003314 2015-07-03
# 1436    7/6/2015 -0.001963 -0.006742 2015-07-06
# 1437    7/7/2015 -0.002136 -0.007607 2015-07-07
# ...          ...       ...       ...        ...
# 1560  12/25/2015  0.000000  0.000000 2015-12-25
# 1561  12/28/2015 -0.002787  0.000000 2015-12-28
# 1562  12/29/2015  0.001346  0.000000 2015-12-29
# 1563  12/30/2015  0.008153  0.009593 2015-12-30
# 1564  12/31/2015 -0.008063 -0.011450 2015-12-31
#
# [132 rows x 4 columns]

# %%
plt.figure(figsize = (20, 8))
plt.plot(df_spx_ftse_H2_15["new_date"], df_spx_ftse_H2_15["GSPCRet"], color = "midnightblue")
plt.plot(df_spx_ftse_H2_15["new_date"], df_spx_ftse_H2_15["FTSERet"], color = "crimson")
plt.title("S&P vs FTSE Returns (H2 2015)", fontsize = 14, fontweight = "bold")
plt.ylabel("Returns")
plt.xlabel("Date")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %% [markdown]
# # Bar and Line Chart(Pareto)

# %%
from matplotlib.ticker import PercentFormatter

# %%
df_movie_complaints = pd.read_csv("bar_line_chart_homework.csv")
df_movie_complaints
# Out:
#   Movie Theater Goers Complaints  Number of complaints  frequency
# 0        Poor Projection Quality                  3821   0.727532
# 1                     Bad Volume                   684   0.857768
# 2                    Screen Size                   298   0.914509
# 3                      Bad Seats                   232   0.958682
# 4                         Queues                   217   1.000000

# %%
# Creating the pareto chart of the movie goers complaints data by creating a figure with two axes. 
# The top two complaints make up fo around 90% of the overall complaints. 
# If the theaters address the first two or even the first complaint only for the poor projection quality,

# the number of complaints will be reduced drastically.
fig, ax = plt.subplots(figsize = (10, 7))

ax.bar(df_movie_complaints["Movie Theater Goers Complaints"],
       df_movie_complaints["Number of complaints"],
       color = "midnightblue")
ax.set_ylabel("Number of Complaints",
              color = "midnightblue",
              weight = "bold")
ax.tick_params(axis = "y", 
               width = 2, 
               labelsize = "large",
               colors = "midnightblue")
ax1 = ax.twinx()
ax1.set_ylim(0, 1.1) #increase the limit slightly, so the line chart isn't cut
ax1.yaxis.set_major_formatter(PercentFormatter(xmax = 1.0))
ax1.plot(df_movie_complaints["Movie Theater Goers Complaints"],
         df_movie_complaints["frequency"],
         color = "#b60000", 
         marker = "D")
ax1.set_ylabel("Frequency", 
               color = "#b60000", 
               weight = "bold")
ax1.tick_params(axis = "y", 
                colors = "#b60000", 
                width = 2, 
                labelsize = "large")
ax.set_title("Top 5 Movie Goers Complaints Frequency Distribution", fontsize = "14", weight = "bold", color = "midnightblue")
plt.show()

# %% [markdown]
# # Pie Chart

# %%
df_cars= pd.read_csv("E:\\365\\Data Visualization\\4. Pie Chart\\pie_chart_data.csv")
df_cars
# Out:
#   Engine Fuel Type  Number of Cars
# 0           Diesel            2019
# 1              Gas             613
# 2            Other             154
# 3           Petrol            1559

# %%
sns.set_palette('colorblind')
plt.figure(figsize=(10,8))
plt.pie(df_cars["Number of Cars"], labels= df_cars["Engine Fuel Type"].values,
       autopct="%.2f%%",
       textprops={'size':'x-large', 'fontweight':'bold', 'rotation':'30', 'color': 'w'})
plt.title("Cars by Engine Fuel type", fontsize= 14, fontweight='bold')
plt.legend()
plt.savefig("Pie Chart- python")
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
df_student_scores = pd.read_csv("student_scores_data.csv")
df_student_scores
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
plt.figure(figsize = (12, 8))
scatter = plt.scatter(df_student_scores['SAT'],
                      df_student_scores['GPA'], 
                      color = "midnightblue") 
plt.title("GPA and SAT Student Scores", 
          fontsize = 14, 
          weight = "bold")
plt.xlabel("SAT", weight = "bold")
plt.ylabel("GPA", weight = "bold")
plt.show()

# %%
df_auto_insurance = pd.read_csv("regression_auto_insurance_sweden.csv")
df_auto_insurance
# Out:
#     Claims  Payment
# 0      108    392.5
# 1       19     46.2
# 2       13     15.7
# 3      124    422.2
# 4       40    119.4
# ..     ...      ...
# 58       9     87.4
# 59      31    209.8
# 60      14     95.5
# 61      53    244.6
# 62      26    187.5
#
# [63 rows x 2 columns]

# %%
sns.set(rc = {'figure.figsize': (9,6)})
sns.regplot(x = "Claims", 
            y = "Payment", 
            data = df_auto_insurance, 
            scatter_kws = {'color': 'k'}, 
            line_kws = {'color': 'red'})
plt.xlabel("Claims")
plt.ylabel("Payment")
plt.title("Car Insurance Claims and Payment in Sweden", fontsize = 14, weight = "bold")
plt.show()

# %% [markdown]
# What we observe is that there seems to be a linear relationship between the two variables. The higher the insurance claim, the higher the payment it has received.

# %%
sns.lmplot(x = "Claims", 
           y = "Payment", 
           data = df_auto_insurance,  
           height = 8, 
           scatter_kws = {'color': 'k'}, 
           line_kws = {'color': 'red'})
plt.xlabel("Claims")
plt.ylabel("Payment")
plt.title("Car Insurance Claims and Payment in Sweden", fontsize = 14, weight = "bold")
plt.show()

# %% [markdown]
# # Stacked Area Chart

# %%
df_revenue_2020 = pd.read_csv("area_chart.csv")
df_revenue_2020
# Out:
#           Date  International  Domestic  Services
# 0    1/28/2020           3200       300      2000
# 1    2/28/2020           4500       500      2000
# 2    3/28/2020           3000       600      2000
# 3    4/28/2020           2800       500      2000
# 4    5/28/2020           5300       400      2000
# 5    6/28/2020           3800       580      2000
# 6    7/28/2020           3500       490      2000
# 7    8/28/2020           2500       290      2000
# 8    9/28/2020           3400       500      2000
# 9   10/28/2020           5000       600      2000
# 10  11/28/2020           5500       500      2000
# 11  12/28/2020           4700       700      2000

# %%
# This Stacked Area Chart displays the company's monthly revenue for the year 2020.
# For this chart it's important to order the categories from largest to smallest for better readability.
# Make sure you order the colors and labels lists in the same way.
# A bright color (such as yellow) would make the smallest category stand out more, however, 
# for this chart, you're welcome to explore your own color palettes.

colors = ["#215968", "#31859C", "#FFC000"]
labels = ["International", "Services", "Domestic"]
sns.set_style("white")
plt.figure(figsize = (12, 6))
plt.stackplot(df_revenue_2020["Date"],
              df_revenue_2020["International"],
              df_revenue_2020["Services"],
              df_revenue_2020["Domestic"],
              colors = colors,
              edgecolor = 'none')
plt.xticks(df_revenue_2020["Date"], rotation = 45)
plt.legend(labels = labels, loc = "upper left")
plt.ylabel("Revenue in $", fontsize = 13)
plt.title("Revenue Report 2020", fontsize = 14, weight = "bold")
sns.despine()
plt.show()

# %%
df_fuel_engine_types = pd.read_csv("stacked_area_chart_data.csv")
df_fuel_engine_types
# Out:
#     Year    Gas  Petrol  Diesel  Other
# 0   1982      0      94       0      0
# 1   1983      0     347       0      0
# 2   1984    300       0     334      0
# 3   1985   1030    1184     984      0
# 4   1986    511     681    1066    340
# 5   1987   1817    1840     400    940
# 6   1988   2999    1882    2060      1
# 7   1989   2626    1641    1304    330
# 8   1990   1290    3247       1      0
# 9   1991   1566    6776    1063    400
# 10  1992   2358    1925    2824    350
# 11  1993   1231    3375    2302      0
# 12  1994   2386    5691    2569     77
# 13  1995   2373    5115    4563    666
# 14  1996   4264    6792    6996   1235
# 15  1997   7031    7336    7877    370
# 16  1998   5578    7511    8634    310
# 17  1999   4069    6147   16742   1493
# 18  2000   6459   10754   23102    531
# 19  2001   3932    7590   22115   1029
# 20  2002   3375    7069   18144    479
# 21  2003   6032    8518   19605    281
# 22  2004   8332    7978   17400   1821
# 23  2005   5785    7269   23551   1918
# 24  2006   6439   12372   18024   1878
# 25  2007  10902   21258   24683   1525
# 26  2008  12876   22090   25471   1516
# 27  2009   2179    5682   10191   1204
# 28  2010   2649    7222   13150    442
# 29  2011   3893   11628   23221   1688
# 30  2012   1899    8763   27958   1736
# 31  2013   1055    6517   16255    607
# 32  2014    409    1942    4703    329
# 33  2015     50     702    1172    125
# 34  2016      0     108     220     25

# %%
colors = ["#011638", "#7e2987", "ef2026", "FFC000"]
labels = ["Diesel", "Petrol", "Gas", "Other"]
sns.set_style("white")
plt.figure(figsize = (12, 6))
plt.stackplot(df_fuel_engine_types["Year"],
              df_fuel_engine_types["Diesel"],
              df_fuel_engine_types["Petrol"],
              df_fuel_engine_types["Gas"],
              df_fuel_engine_types["Other"],
              colors = colors,
              edgecolor = 'none')
plt.xticks(df_fuel_engine_types["Year"], rotation = 45)
plt.legend(labels = labels, loc = "upper left")
plt.ylabel("Number of Cars", fontsize = 13)
plt.title("Popularity of Engine Fuel Types (1982 - 2016)", fontsize = 14, weight = "bold")
sns.despine()
plt.show()
